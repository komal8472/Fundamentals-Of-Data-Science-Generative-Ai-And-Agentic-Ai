# %% [markdown]
# # Conditional Statement

# %% [markdown]
# -if
#
# -else
#
# -nested if
#
# -if elif else

# %%
if True:
    print('data science')
# Out:
# data science

# %%
if False:
    print('data science')
print(' no job')
# Out:
#  no job

# %%
if True:
    print('data science')
print('no job')
# Out:
# data science
# no job

# %%
if True:
    print('data science')
else:
    print('no job')
# Out:
# data science

# %%
if False:
    print('data science')
else:
    print('no job')
# Out:
# no job

# %%
x=4
r=x%2

if r==0:
    print('even number')
# Out:
# even number

# %%
x=5
r=x%2

if r!=0:
    print('odd number')
# Out:
# odd number

# %%
x=5
r=x%2

if r==0:
    print('even number')

# %%
x=4
r=x%2

if r==0:
    print('even number')
# Out:
# even number

# %%
x=7
r=x%2

if r==1:
    print('odd number')
# Out:
# odd number

# %%
x=4
r=x%2

if r==0:
    print('even number')
print('odd number')
# Out:
# even number
# odd number

# %%
x=5
r=x%2

if r==0:
    print('odd number')

# %%
x=9
r=x%2

if r==0:
    print('even number')
if r==1:
    print('odd number')
# Out:
# odd number

# %%
x=8
r=x%2

if r==0:
    print('even number')
if r==1:
    print('odd number')
# Out:
# even number

# %%
x=3
r=x%2

if r==0:
    print('even number')
if x>5:
    print('odd number')
else:
    print('odd number')
# Out:
# odd number

# %%
x=4
r=x%2

if r==0:
    print('even number')
if x>5:
    print('greater number')
else:
    print('odd number')
# Out:
# even number
# odd number

# %%
x=4
r=x%2

if r==0:
    print('even number')
    if x>5:
        print('greater number')
    else:
        print('lesser number')
else:
    print('odd number')
# Out:
# even number
# lesser number

# %%
x=13
r=x%2

if r==0:
    print('even number')
    if x>5:
        print('greater number')
    else:
        print('lesser number')
else:
    print('odd number')
# Out:
# odd number

# %%
x=3

if x==1:
    print('one')
if x==2:
    print('two')
if x==3:
    print('three')
if x==4:
    print('four')
# Out:
# three

# %%
x=1

if x==1:
    print('one')
elif x==2:
    print('two')
elif x==3:
    print('three')
# Out:
# one

# %%
x=5

if x==1:
    print('one')
if x==2:
    print('two')
if x==3:
    print('three')
if x==4:
    print('four')
else:
    print('number not found')
# Out:
# number not found

# %%
age=19
if age>18:
    print('eligible for vote')
# Out:
# eligible for vote
