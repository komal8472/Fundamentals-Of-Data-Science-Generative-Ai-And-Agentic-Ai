# %% [markdown]
# # Typecasting

# %% [markdown]
# float to int ---- possible
#
# str to int ----- possible
#
# int to bool ----- possible
#
# intbto string ----- impossible

# %%
int(2.5)
# Out:
# 2

# %%
int('10')
# Out:
# 10

# %%
int('komal')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('komal')
#
# ValueError: invalid literal for int() with base 10: 'komal'

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# in typecasting we cannot convert text string to int , complex to int , user cannot define 2 argument at once

# %% [markdown]
# float to int ---- possible
#
# float to str ----- possible
#
# float to bool ---- possible
#
# float to complex ---- impossible

# %%
float(30000)
# Out:
# 30000.0

# %%
float('10')
# Out:
# 10.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(10+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 float(10+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
import numpy as np
a=np.nan
print(type(a))
# Out:
# <class 'float'>

# %% [markdown]
# int to str --- possible
#
# float to str ---- possible
#
# complex to str ----- possible
#
# bool to str -----possible

# %%
str(7)
# Out:
# '7'

# %%
str(8.7)
# Out:
# '8.7'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %% [markdown]
# non zero argument if you define it will detect as true ----ex -bool(1.5)
#
# zero argument then it will detect false-----ex -bool()

# %%
str(True)
# Out:
# 'True'

# %%
str()
# Out:
# ''

# %%
bool(10)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(1.5)
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10.5,20)
# Out:
# (10.5+20j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10,20')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 complex('10,20')
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# # Data Structure

# %% [markdown]
# in data structure user can declare more than 1 value

# %%
i=34
i
# Out:
# 34

# %%
id(i)
# Out:
# 140706473559880

# %%
p=20
q=30
r=40

# %%
print(id(p))
print(id(q))
print(id(r))
# Out:
# 140706473559432
# 140706473559752
# 140706473560072

# %%
a='hello'

# %%
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
# Out:
# h
# e
# l
# l
# o

# %%
print(a[-1])
print(a[-2])
print(a[-3])
print(a[-4])
print(a[-5])
# Out:
# o
# l
# l
# e
# h

# %%
str='hello'
str
# Out:
# 'hello'

# %%
len(str)
# Out:
# 5

# %%
print(str[0:4])
# Out:
# hell

# %%
print(str[0:5])
# Out:
# hello

# %%
s='hellopython'
s
# Out:
# 'hellopython'

# %%
print(s[0:10:1])
# Out:
# hellopytho

# %%
print(s[0:10:2])
# Out:
# hloyh

# %%
print(s[::1])
# Out:
# hellopython

# %%
s[1:8:2]
# Out:
# 'elpt'

# %% [markdown]
# # string concatination

# %%
a='hello'
b='python'

# %%
c=a+b
print(c)
# Out:
# hellopython
