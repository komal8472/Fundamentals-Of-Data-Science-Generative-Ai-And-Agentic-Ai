# %%
# python variable = identifier = object

# %%
# syntax (variable = value)

# %%
# Rules to declare python variable

# %% [markdown]
# 1. python variable is case sensitive

# %%
var=6
VAR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 var=6
# ----> 2 VAR
#
# NameError: name 'VAR' is not defined

# %% [markdown]
# 2. special symbol not allowed in the variable only underscore is allowed

# %%
v@=20
v@
# Out:
#   Cell In[9], line 2
#     v@
#       ^
# SyntaxError: invalid syntax

# %%
v_=20
v_
# Out:
# 20

# %% [markdown]
# 3.variable does not start with digit but ends with digit

# %%
1var=30
1var
# Out:
#   Cell In[11], line 1
#     1var=30
#     ^
# SyntaxError: invalid decimal literal

# %%
var1=30
var1
# Out:
# 30

# %%
'1var'=40
'1var'
# Out:
#   Cell In[13], line 1
#     '1var'=40
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# 4. keyword and reserved word can never be a variable

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for=8                # beacuse it is keyword
# Out:
#   Cell In[16], line 1
#     for=8                # beacuse it is keyword
#        ^
# SyntaxError: invalid syntax

# %%
FOR=8
FOR
# Out:
# 8

# %% [markdown]
# # Data Types

# %% [markdown]
# 1. int
#
# 2. float
#
# 3. bool
#
# 4. string
#
# 5. complex

# %% [markdown]
# # 1. integer

# %% [markdown]
#  integer means values without decimal

# %%
i=10
i
# Out:
# 10

# %%
type(i)
# Out:
# int

# %% [markdown]
# # 2. Float

# %% [markdown]
# float means values with decimal

# %%
f=10.5
f
# Out:
# 10.5

# %%
type(f)
# Out:
# float

# %%
i+f
# Out:
# 20.5

# %%
i-f
# Out:
# -0.5

# %%
i*f
# Out:
# 105.0

# %% [markdown]
# # 3. boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
True-False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
True//True
# Out:
# 1

# %%
True/True
# Out:
# 1.0

# %% [markdown]
# # string

# %% [markdown]
# string always declare with ''|""|''' '''
#
#
# ''' ''' we use for multiline comment

# %%
s='hello'
s
# Out:
# 'hello'

# %%
s="hello"
s
# Out:
# 'hello'

# %%
s='''hello'''
s
# Out:
# 'hello'

# %%
s1='''hello
         team'''
s
# Out:
# 'hello'

# %% [markdown]
# # 5. complex

# %% [markdown]
# a+bj
#
# a -- real part
#
# b -- imaginary part
#
# c --square root of -1

# %%
c=10+20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c=10+20j
d=20+30j
print(c+d)
# Out:
# (30+50j)

# %%
print(c-d)
# Out:
# (-10-10j)

# %%
print(c*d)
# Out:
# (-400+700j)
