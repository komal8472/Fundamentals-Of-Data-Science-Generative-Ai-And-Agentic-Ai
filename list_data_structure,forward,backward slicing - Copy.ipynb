# %% [markdown]
# # Data structure

# %% [markdown]
# List
#
# Tuple
#
# Set
#
# Dictionary
#
# Range

# %% [markdown]
# # 1. List

# %%
l=[]
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 l.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
l.append(100)

# %%
l
# Out:
# [100]

# %%
l.append(10)
l.append(20)
l.append(30)

# %%
l
# Out:
# [100, 10, 20, 30]

# %%
len(l)
# Out:
# 4

# %%
l.append(50)

# %%
l
# Out:
# [100, 10, 20, 30, 50]

# %%
l1=[30,40,'ten',2.3,2+4j]

# %%
l1
# Out:
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
print(l)
print(l1)
# Out:
# [100, 10, 20, 30, 50]
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 5

# %%
print(id(l))
print(id(l1))
# Out:
# 1785057403008
# 1785066813888

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l2=l1.copy()
l2
# Out:
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
l1==l2
# Out:
# True

# %%
l==l2
# Out:
# False

# %%
print(l)
print(l1)
print(l2)
# Out:
# [100, 10, 20, 30, 50]
# [30, 40, 'ten', 2.3, (2+4j)]
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
l != l2
# Out:
# True

# %%
l
# Out:
# [100, 10, 20, 30, 50]

# %%
l[:]
# Out:
# [100, 10, 20, 30, 50]

# %%
l[0]
# Out:
# 100

# %%
l[-1]
# Out:
# 50

# %%
l
# Out:
# [100, 10, 20, 30, 50]

# %%
l[4]
# Out:
# 50

# %%
l[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l[5]
#
# IndexError: list index out of range

# %%
l[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 l[10]
#
# IndexError: list index out of range

# %%
l
# Out:
# [100, 10, 20, 30, 50]

# %%
l[0]=60

# %%
l
# Out:
# [60, 10, 20, 30, 50]

# %%
l[-1]='jan'

# %%
l
# Out:
# [60, 10, 20, 30, 'jan']

# %%
l.append('feb')

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb']

# %%
l.append(40)

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40]

# %%
l.append(20)

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l2
# Out:
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
len(l2)
# Out:
# 5

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l.count(100)
# Out:
# 0

# %%
l.count(20)
# Out:
# 2

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l.count(10000)
# Out:
# 0

# %%
print(l)
print(l1)
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
print(len(l))
print(len(l1))
# Out:
# 8
# 5

# %% [markdown]
# # List Membership

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
100 in l
# Out:
# False

# %%
20 in l
# Out:
# True

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l1
# Out:
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
l2=[]

# %%
print(len(l))
print(len(l1))
print(len(l2))
# Out:
# 8
# 5
# 0

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l1
# Out:
# [30, 40, 'ten', 2.3, (2+4j)]

# %%
l2
# Out:
# []

# %%
l2.extend(l)

# %%
l2
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l2.extend(l1)

# %%
print(l2)
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l1.extend(l2)

# %%
print(l1)
# Out:
# [30, 40, 'ten', 2.3, (2+4j), 60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
len(l1)
# Out:
# 18

# %%
l
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l.index('jan')
# Out:
# 4

# %%
l[:]
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]

# %%
l2
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l2[:]
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l2[0:7]
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40]

# %%
l2[3:10]
# Out:
# [30, 'jan', 'feb', 40, 20, 30, 40]

# %%
l2[::2]
# Out:
# [60, 20, 'jan', 40, 30, 'ten', (2+4j)]

# %%
l2[::5]
# Out:
# [60, 'feb', 'ten']

# %% [markdown]
# # Backward indexing and Backward indexing

# %%
l2
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l2[:]
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l2[-5]
# Out:
# 30

# %%
l2[-9]
# Out:
# 'jan'

# %%
l2[:-3]
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40]

# %%
l2[-3:]
# Out:
# ['ten', 2.3, (2+4j)]

# %%
l2
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l2[3:-3]
# Out:
# [30, 'jan', 'feb', 40, 20, 30, 40]

# %%
l2[::-1]
# Out:
# [(2+4j), 2.3, 'ten', 40, 30, 20, 40, 'feb', 'jan', 30, 20, 10, 60]

# %%
l2
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l2[:-3]
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40]

# %%
l2[::-3]
# Out:
# [(2+4j), 40, 40, 30, 60]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [60, 10, 20, 30, 'jan', 'feb', 40, 20]
# [30, 40, 'ten', 2.3, (2+4j), 60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]
# [60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
l1.remove(2+4j)

# %%
print(l1)
# Out:
# [30, 40, 'ten', 2.3, 60, 10, 20, 30, 'jan', 'feb', 40, 20, 30, 40, 'ten', 2.3, (2+4j)]

# %%
txt='abcd efghi jklm '
txt.lstrip()
# Out:
# 'abcd efghi jklm '

# %%
txt='abcd efghi jklm'
txt.strip()
# Out:
# 'abcd efghi jklm'

# %% [markdown]
# # using Escape character

# %%
#using double quotes in the string is not allowed
mystr="my favourite game is"cricket""
# Out:
#   Cell In[99], line 2
#     mystr="my favourite game is"cricket""
#                                 ^
# SyntaxError: invalid syntax

# %%
#using escape character to allow illegal characters
mystr="my favourite game is \"cricket\""
print(mystr)
# Out:
# my favourite game is "cricket"

# %% [markdown]
# # List

# %% [markdown]
# list is an ordered sequences of items
#
# we can have diffrent data types under a list.
#
# eg : we can have integer , float and string items in a same list

# %% [markdown]
# # List creation

# %%
list1=[]      #empty list

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2=[10,30,20]   #list of integer numbers
list2
# Out:
# [10, 30, 20]

# %%
list3=[30.0,2.4,1.3,3.2]   #list of floating numbers
list3
# Out:
# [30.0, 2.4, 1.3, 3.2]

# %%
list4=['komal','shubham','karegaonkar']   #list of string
list4
# Out:
# ['komal', 'shubham', 'karegaonkar']

# %%
list5=['komal','shubahm',5,[1,2,3,'four']]   #nested list
list5
# Out:
# ['komal', 'shubahm', 5, [1, 2, 3, 'four']]

# %%
list6=[1,2.8,'komal',True]  #list of mix datatype
list6
# Out:
# [1, 2.8, 'komal', True]

# %%
list7=['komal','shubham',[1,2],{'navira'}]
list7
# Out:
# ['komal', 'shubham', [1, 2], {'navira'}]

# %%
len(list6)
# Out:
# 4

# %% [markdown]
# # List indexing

# %% [markdown]
# Forward indexing

# %%
list5
# Out:
# ['komal', 'shubahm', 5, [1, 2, 3, 'four']]

# %%
list5[0]  #retrive first element of the list
# Out:
# 'komal'

# %%
list3
# Out:
# [30.0, 2.4, 1.3, 3.2]

# %%
list3[0]   #retrive first element of the list
# Out:
# 30.0

# %%
list4
# Out:
# ['komal', 'shubham', 'karegaonkar']

# %%
list4[0][0]    #nested indexing : access the first character of the first list element
# Out:
# 'k'

# %% [markdown]
# # Backward indexing

# %%
list4[-1]   #last item of the list
# Out:
# 'karegaonkar'

# %%
list5[-1]  # last item of the list
# Out:
# [1, 2, 3, 'four']

# %%
list5[-3]
# Out:
# 'shubahm'

# %% [markdown]
# # List slicing

# %%
mylist=['one','two','three','four','six','seven','eight']
mylist
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight']

# %%
mylist[0:3]   #return all items from 0th to 3rd index location including item
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5]
# Out:
# ['three', 'four', 'six']

# %%
mylist[:3]   #return first three items
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2]   #return first two item
# Out:
# ['one', 'two']

# %%
mylist[-3:]    #return last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:]
# Out:
# ['seven', 'eight']

# %%
mylist[-1]         #return last item in the list
# Out:
# 'eight'

# %%
mylist[:]            #return whole list
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight']

# %% [markdown]
# # Add remove and change items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight']

# %%
mylist.append('nine')    #add an item to end of the list

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight', 'nine']

# %%
mylist.insert(9,'ten')  #add item at

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.insert(1,'ONE')

# %%
mylist
# Out:
# ['one', 'ONE', 'two', 'three', 'four', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.remove('ONE')    #remove item ONE

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop()
# Out:
# 'ten'

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight', 'nine']

# %%
del mylist[7]

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'six', 'seven', 'eight']

# %%
#change value of the string

mylist[0]=1
mylist[1]=2
mylist[2]=3

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.clear()   #delete all the items in the list / empty list
mylist
# Out:
# []

# %%
del mylist
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 del mylist
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# # Copy list

# %%
mylist=['one','two','three','four','five','six','seven','eight']
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist1=mylist   #crete a new reference mylist1
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
id(mylist),id(mylist1)   #the address of both mylist and mylist1 will be the same
# Out:
# (2800297300544, 2800297300544)

# %%
mylist2=mylist1.copy()   #create a copy of list

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
id(mylist2)    # The address of mylist2 will be different from mylist because mylist
# Out:
# 2800297349696

# %%
mylist[0]=1

# %%
mylist  #mylist will be also impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist2   #copy of list wont be impacted due to changes made on the original list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # Join list

# %%
list1=['one','two','three','four']
list2=['five','six','seven','eight']
list3=list1+list2    #join two list by '+' operator
print(list3)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2)  #append list2 with list1
print(list1)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # List Membership

# %%
print(list1)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1      #check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1      #check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in list1:
    print('three present in the list')
else:
    print('three not present in the list')
# Out:
# three present in the list

# %%
if 'eleven' in list1:
    print('eleven present in the list')
else:
    print('eleven not present in the list')
# Out:
# eleven not present in the list

# %% [markdown]
# # Reverse and sort list

# %%
print(list1)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()      #reverse the list
print(list1)
# Out:
# ['eight', 'seven', 'six', 'five', 'eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1=list1[::-1]     #reverse the list
print(list1)
# Out:
# ['eight', 'seven', 'six', 'five', 'eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
mylist3=[9,12,98,99,34,5]
mylist3.sort()       #sort list in ascending order
mylist3
# Out:
# [5, 9, 12, 34, 98, 99]

# %%
mylist3.sort(reverse=True)       #sort list in descending order
mylist3
# Out:
# [99, 98, 34, 12, 9, 5]

# %%
mylist4=[88,65,33,21,11,98]
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %%
sorted(mylist4)      #return a new sorted list and doesnt change original list
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %%
mylist4.sort(reverse=True)

# %%
mylist4
# Out:
# [98, 88, 65, 33, 21, 11]

# %% [markdown]
# # Loop through a list

# %%
print(list1)
# Out:
# ['eight', 'seven', 'six', 'five', 'eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
for i in list1:
    print(i)
# Out:
# eight
# seven
# six
# five
# eight
# seven
# six
# five
# four
# three
# two
# one

# %%
for i in enumerate (list1):
    print(i)
# Out:
# (0, 'eight')
# (1, 'seven')
# (2, 'six')
# (3, 'five')
# (4, 'eight')
# (5, 'seven')
# (6, 'six')
# (7, 'five')
# (8, 'four')
# (9, 'three')
# (10, 'two')
# (11, 'one')

# %% [markdown]
# # Count

# %%
list10=['one','two','three','four','one','one','two','three']

# %%
list10.count('one')       #number of times item 'one' occured in list
# Out:
# 3

# %%
list10.count('two')
# Out:
# 2

# %%
list10.count('four')
# Out:
# 1

# %% [markdown]
# # All / Any

# %% [markdown]
# The all method returns :
#
#     True --If all elements in the lists are true
#
#     False--If any elements in the list is false
#
# The any() function returns True if any element in the list is True.If not,any() returns False

# %%
l1=[1,2,3,4,0]           # Will Return false as one value is false (Value 0)

# %%
all(l1)
# Out:
# False

# %%
any(l1)
# Out:
# True

# %%
l2=[1,2,3,True,False]

# %%
all(l2)  # Returns false as one value is false
# Out:
# False

# %%
any(l2)    # Will Return True as we have items in the list with True value
# Out:
# True

# %%
l3=[1,2,3,True]
all(l3)     # Will return True as all items in the list are True
# Out:
# True

# %%
any(l3)
# Out:
# True
