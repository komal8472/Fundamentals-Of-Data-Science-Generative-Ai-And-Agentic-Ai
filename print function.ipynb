# %%
# print is use for answer

# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('hello')
print(10,20,'hello')
# Out:
# 10
# 10 20
# hello
# 10 20 hello

# %%
num1=10
num2=20
add=num1+num2
print(add)
# Out:
# 30

# %% [markdown]
# # print result with string

# %%
num1=10
num2=10
add=num1+num2
print('the addition of',num1,'and', num2, 'is:',add)
# Out:
# the addition of 10 and 10 is: 20

# %%
name='komal'
age=21
city='hydrabad'
#hello my name is komal and i am 21 years old from hydrabad

# %%
print('my name is',name,'and i am',age,'years old from',city )
# Out:
# my name is komal and i am 21 years old from hydrabad

# %% [markdown]
# # print format method

# %%
num1=20
num2=30
add=num1+num2
print('addition of {} and {} is={}'.format(num1,num2,add))
# Out:
# addition of 20 and 30 is=50

# %%
print('the addition of {} and {} is={}'.format(num1,num2,add) )
# Out:
# the addition of 20 and 30 is=50

# %% [markdown]
# first decide how to print should be
#
# like:-the addition of 20 and 30 is :50
#
# then the replace variable position with curley bratacesm {}
#
# then apply .format(val1,val2,val-n methdom)

# %%
name='koaml'
age='21'
city='hydrabad'

# %%
print('my name is {} and i am {} years old from {}'.format(name,age,city))
# Out:
# my name is koaml and i am 21 years old from hydrabad

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3 # or we can use avg round(num1+num2+num3)/3,2
avg1=round(num1+num2+num3)/3,2
print('the average of {},{} and {} is={} or {}'.format(num1,num2,num3,avg,avg1))
#here we can use round (avg,2) also 
round(avg,2)   # round of till 2 digit after deciaml
# Out:
# the average of 100,25 and 333 is=152.66666666666666 or (152.66666666666666, 2)
# 152.67

# %% [markdown]
# # more short format method (f string method)
#
# variable should be in curly braces
#
# and write everything inside quotes''
#
# at starting simply add f

# %%
num1=20
num2=30
add=num1+num2
print(f'the addition of {num1} and {num2} is = {add}')
# Out:
# the addition of 20 and 30 is = 50

# %%
name='komal'
age=21
city='hydrabad'
print(f'My name is {name} and i am {age} years old from {city} ')
# Out:
# My name is komal and i am 21 years old from hydrabad

# %%
num1=100
num2=25
num3=333
avg=(round(num1+num2+num3)/3)

# %%
print(f'the average of {num1},{num2} and {num3} is ={avg}')
# Out:
# the average of 100,25 and 333 is =152.66666666666666

# %%
# let combine all

num1=10
num2=20
add=num1+num2

print('the addition of', num1, 'and', num2 ,'is=',add)

print('the additiom of {} and {} is = {}'.format(num1,num2,add))

print(f'the addition of {num1} and {num2} is = {add}')
# Out:
# the addition of 10 and 20 is= 30
# the additiom of 10 and 20 is = 30
# the addition of 10 and 20 is = 30

# %% [markdown]
# # End statement

# %%
print('Hello')          #1st statement
print('Good morning')   #2nd statement
# i want to print like :- hello good morning
# Out:
# Hello
# Good morning

# %% [markdown]
# here we will use end statement that joint line from end of one string to starting of other string

# %%
print('hello',end =' ')
print('good morning')
# Out:
# hello good morning

# %% [markdown]
# here one print statement only we use
#
# inside one print statement we have multiple values
#
# we want to seperate these multiple values with anything

# %% [markdown]
# # Seprator

# %%
print('hello','hi','how are you',sep='---->')
# Out:
# hello---->hi---->how are you

# %%
print('hello','hi','how are you',sep='@')
# Out:
# hello@hi@how are you

# %%
print('hello ' , ' good morning',sep='')
# Out:
# hello  good morning

# %%
print(3,'.')       # is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.',sep='')    #see now space setteled (also use to remove space B/W words)
# Out:
# 3.

# %%
print(1,2,3,end='')
print('3',', sep')
# Out:
# 1 2 33 , sep
