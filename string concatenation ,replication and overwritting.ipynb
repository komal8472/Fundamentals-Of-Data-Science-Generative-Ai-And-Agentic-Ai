# %% [markdown]
# # string concatenation and replication

# %%
"komal" + "karegaonkar"
# Out:
# 'komalkaregaonkar'

# %%
"komal" + 98
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 "komal" + 98
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# one string value and one integer value (*) its use to string replication

# %%
"komal" * 3
# Out:
# 'komalkomalkomal'

# %%
spam =20
spam
# Out:
# 20

# %%
eggs=2
eggs+spam
# Out:
# 22

# %%
spam+eggs+spam
# Out:
# 42

# %%
spam=spam+5
spam
# Out:
# 35

# %% [markdown]
# # staring overwriting

# %%
spam="komal"
spam
# Out:
# 'komal'

# %%
print('hi,i am shubham')
print('what is your name ?')
my_name=input('>')
print('what is your age ?')
my_age=input('>')
print('you will be '   +   str(int(my_age)+1)   +   ' in a years ')
print('it good to meet you ' + my_name)
# Out:
# hi,i am shubham
# what is your name ?
# > komal
# what is your age ?
# > 21
# you will be 22 in a years
# it good to meet you komal

# %%
print('the length of your name is:')
print(len(my_name))
# Out:
# the length of your name is:
# 5

# %% [markdown]
# + operator can be used only add two numbers or concatenate two strings
#
#
#
#   you cant add an integer to a string this is not allowed in python

# %%
print('i am' + 21 + 'years old')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print('i am' + 21 + 'years old')
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('i am ' + str(21) +  '  years old')
# Out:
# i am 21  years old

# %%
spam=input()
# Out:
#  50

# %%
spam=int(spam)
spam
# Out:
# 50

# %%
10/5
# Out:
# 2.0

# %%
spam*10/5
# Out:
# 100.0

# %%
int(5.7)
# Out:
# 5

# %%
int(5.7)+1
# Out:
# 6

# %%
a=5
print(a)
# Out:
# 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b='komal'
print(len(b))
# Out:
# 5

# %% [markdown]
# # round() function

# %% [markdown]
# the round() function accpect a float value and returns nearest integer value

# %%
round(3.14)
# Out:
# 3

# %%
round(5.7)
# Out:
# 6

# %%
round(3.14,1)
# Out:
# 3.1

# %% [markdown]
# round(3.14,2)

# %%
round(3.146786,3)
# Out:
# 3.147

# %% [markdown]
# # what is encoding ?
#
#  a system representing text as a numbers is called an encoding

# %% [markdown]
# # 2. boolean operator

# %% [markdown]
# True and True ------True
#
# False and False ------ False
#
# True and False ------False
#
# False and True -----False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
name='komal'
if name=='komal':
    print('hi,komal')
# Out:
# hi,komal

# %%
name='komal'
if (name!='komal'):
    print('hi , komal')
else:
    print('hello stranger')
# Out:
# hello stranger

# %%
name='komal'
age=21
if name=='komal':
    print('hi komal')
elif age<12:
    print('you are not komal, kiddo')
# Out:
# hi komal

# %%
spam=0
if spam<5:
    print('hello world')
    spam=spam+1
else:
    print('good morning')
# Out:
# hello world

# %%
spam=10
if spam<10:
    print('hi')
    spam=spam+1    #spam=10+1=11-----11<10
else:
    print('hello')
# Out:
# hello
